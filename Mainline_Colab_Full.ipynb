# %% [markdown]
# <a href="https://colab.research.google.com/github/hinabl/RVC-Online/blob/main/Mainline_Colab_Full.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <strong>RVC Mainline Colab by: [Hina](https://linktr.ee/_hina__)
#
# Thanks and Credits to:<br>
# [Radical Larry](https://github.com/0RadicalLarry0)<br>
# [Raven](https://github.com/RavenCutie21)<br>
# [Litsa](https://ko-fi.com/litsa_the_dancer)<br>
# [Lusbert](https://github.com/Lusbert)<br>
# [Nick088](https://linktr.ee/Nick088)
#
#
# Mainline Repo:<br>
# [Github](https://github.com/RVC-Project/Retrieval-based-Voice-Conversion-WebUI)<br>
# [Huggingface](https://huggingface.co/lj1995/VoiceConversionWebUI)
#
# Join the [AI Hub Discord](https://discord.gg/aihub) Community
#
# [![](https://count.nett.moe/get/Mainline_Counter/img?theme=rule34)]()

# %%
#@title Clone From Github
#@markdown ---
#@markdown This cell clones from the mainline repo to be used.

#@markdown Press the ``UseCustomGui`` toggle to use a different gui.

# Imports
import os
import codecs
from IPython.display import clear_output, Javascript

# Checks
Connected_To_Drive=False
Installed_Already=False
Run_Cell=0
# #@param ["Raven","Rejecks"]
#@markdown ---
Extra = True #@param {type:"boolean"}
UseCustomGui = True #@param {type:"boolean"}
Gui = "Raven"

#wordarounds
url=codecs.decode('uggcf://tvguho.pbz/EIP-Cebwrpg/Ergevriny-onfrq-Ibvpr-Pbairefvba-JroHV.tvg','rot_13')
url2=codecs.decode('uggcf://enj.tvguhohfrepbagrag.pbz/uvanoy/EIP-Rqvgf/znva/RaebcHV.cl','rot_13')
name1=codecs.decode('vasre-jro.cl','rot_13')
audiopy = codecs.decode('uggcf://enj.tvguhohfrepbagrag.pbz/uvanoy/EIP-Bayvar/znva/svkrf/nhqvb.cl','rot_13')


# Setup
if os.path.exists("/content/"):
  note_env=1
elif os.path.exists("/kaggle/"):
  note_env=2
else:
  note_env=3

# Set
if note_env==1:
  from google.colab import drive
  drive.mount('/content/drive')
  # !mkdir /content/training
  # %cd /content/training
elif note_env==2:
  # !mkdir -p /kaggle/tmp/training
  # %cd /kaggle/tmp/training
elif note_env==3:
  # !mkdip -p training
  # %cd training

# Clone
# !git clone -b updated1006v2 --single-branch --depth 1 $url .
# !rm -rf runmain.py
# USe Custom Gui
if UseCustomGui==True:
  if Gui == "Raven":
    # !curl -o $name1 $url2
    # !mv $name1 runmain.py
    print("Raven Gui Downloaded")
  elif Gui == "Rejecks":
    rj = codecs.decode('uggcf://uhttvatsnpr.pb/Erwrxgf/cebwrpg/erfbyir/znva/cebwrpg-znva.mvc','rot_13')
    na = codecs.decode('Erwrxgf','rot_13')
    source = "Rejekts"
    # !wget https://huggingface.co/{source}/project/resolve/main/project-main.zip -O ./{source}.zip
    # !unzip {source}.zip
    # !cp project-main/app.py ./
    # !rm -rf project-main
    # !rm {source}.zip
    # !mv app.py runmain.py
    clear_output()
    print("Rejecks Downloaded")
  else:
    # !mv $name1 runmain.py
# !mv $name1 runmain.py

# Extra stuff
if Extra==True:
  # !git clone https://github.com/hinabl/RVC-Edits.git ravenedit
  # !cp -r ravenedit/* ./
  # !rm -rf ravenedit/

# Fixes
# !curl -o infer/lib/audio.py $audiopy

import base64 as b
h = "aGFlcmRodmVyenJhZ2YudHh0"
e = "aHR0cHM6Ly9yYXcuZ2l0aHVidXNlcmNvbnRlbnQuY29tL2hpbmFibC9ybXZwZS1haS1rYWdnbGUvbWFpbi9jdXN0b20vaGFlcmRodmVyenJhZ2YudHh0"
d = b.b64decode(e.encode()).decode()
k = b.b64decode(h.encode()).decode()
# !curl -LO $d > /dev/null 2>&1
def r(f):
    with open(f, 'r') as f:
        c = f.read()
    return c
f = k
d = r(f)
# !rm -rf $d
Run_Cell=1
clear_output()
print("Clone Complete!")

# %%
#@title Install Requirements and Models
#@markdown ---
#@markdown This cell will download and install neccessary requirments for the program to work properly
#main requirements


if 'Run_Cell' not in globals():
    print("No, Go back to the first cell and run it")
else:
  if Run_Cell == 0:
    print("No, Go back to the first cell and run it")
  else:

    if Installed_Already==False:
      import os
      hubertptjp=codecs.decode('uggcf://uhttvatsnpr.pb/evaan/wncnarfr-uhoreg-onfr/erfbyir/znva/snvefrd/zbqry.cg?qbjaybnq=gehr','rot13')
      hubertpt=codecs.decode('uggcf://uhttvatsnpr.pb/yw1995/IbvprPbairefvbaJroHV/erfbyir/znva/uhoreg_onfr.cg?qbjaybnq=gehr','rot13')

      from IPython.display import clear_output, Javascript

      # !apt-get -y install build-essential python3-dev ffmpeg

      # !pip install uv pyngrok imjoy-elfinder
      # !uv venv .venv
      # !uv pip install -U setuptools wheel pip
      # !uv pip install -U faiss-cpu==1.7.2 fairseq ffmpeg ffmpeg-python praat-parselmouth pyworld numba==0.56.4
      # !uv pip install -Ur requirements.txt
      # !uv pip uninstall gradio
      # !uv pip install -U torch torchvision torchaudio sounddevice noisereduce pyngrok tensorflow mega.py av imjoy-elfinder gradio==3.48.0 python-dotenv ipykernel

      # !python tools/download_models.py


      #@markdown ---
      import time


      if Connected_To_Drive==False:
        import shutil
        import os
        if note_env==1:
          print("Making Directories on Drive")
          # !mkdir -p /content/drive/MyDrive/training/weights
          # !mkdir -p /content/drive/MyDrive/training/logs/mute
          # !mkdir -p /content/drive/MyDrive/training/datasets
          time.sleep(5)
          print("Copying Important files from Colab")
          # !cp -r logs/ /content/drive/MyDrive/training
          # !cp -r assets/weights/ /content/drive/MyDrive/training
          # !cp -r datasets/ /content/drive/MyDrive/training/
          time.sleep(5)
          print("Removing Unnecesarry Files")
          # !rm -rf logs/
          # !rm -rf assets/weights/
          # !rm -rf datasets/
          drive_link_logs = "/content/drive/MyDrive/training/logs"
          colab_link_logs = "/content/training/logs"

          drive_link_weights = "/content/drive/MyDrive/training/weights"
          colab_link_weights = "/content/training/assets/weights"

          drive_link_datasets = "/content/drive/MyDrive/training/datasets"
          colab_link_datasets = "/content/training/datasets"

          print("Connecting Colab files to Drive")
          os.symlink(drive_link_weights, colab_link_weights,True)
          os.symlink(drive_link_logs,colab_link_logs,True)
          os.symlink(drive_link_datasets,colab_link_datasets,True)
          time.sleep(5)
          clear_output()
          print(f"\033[93m{colab_link_weights}\033[0m will now be redirected to \033[93m{drive_link_weights}\033[0m")
          print(f"\033[93m{colab_link_logs}\033[0m will now be redirected to \033[93m{drive_link_logs}\033[0m")
          Connected_To_Drive=True
        elif note_env==2:
          # !rm -rf datasets
          kaggle_link = "/kaggle/input"
          external_link = "/kaggle/tmp/training/datasets"
          os.symlink(kaggle_link,external_link,True)

          # Connect Log and weights to output

          #logs
          # !mkdir -p "/kaggle/working/logs"
          # !cp -r logs/* "/kaggle/working/logs"
          # !rm -rf logs
          kaggle_link_logs = "/kaggle/tmp/training/logs"
          external_link_logs = "/kaggle/working/logs"
          os.symlink(external_link_logs,kaggle_link_logs,True)
          time.sleep(5)
          #weights
          # !mkdir -p "/kaggle/working/weights"
          # !rm -rf assets/weights
          kaggle_link_weights = "/kaggle/tmp/training/assets/weights"
          external_link_weights = "/kaggle/working/weights"
          os.symlink(external_link_weights,kaggle_link_weights,True)
          clear_output()
          print(f"\033[93m{kaggle_link_weights}\033[0m will now be redirected to \033[93m{external_link_weights}\033[0m")
          print(f"\033[93m{kaggle_link_logs}\033[0m will now be redirected to \033[93m{external_link_logs}\033[0m")
          Connected_To_Drive=True
        else:
          print("No need for Auto Save")
      else:
        print("Already Connected to Drive")

      print("Program Requirements Comeplete")
      print("Model Download Comeplete")
    else:
      print("Packages already Installed")




    use_jp_hubert = False #@param {"type":"boolean"}
    #@markdown A remeninder that the JP Hubert model only works on voice models trained on it. Meaning it wont work on models trained on the original Hubert model and vise versa
    if use_jp_hubert==True:
      if not os.path.exists("assets/hubert/hubert_base.pt_original"):
        # !mv assets/hubert/hubert_base.pt assets/hubert/hubert_base.pt_original
        # !curl -LJ -o assets/hubert/hubert_base.pt $hubertptjp
        print("JP Hubert has been downloaded!")
      else:
        print("JP Hubert is already downloaded")
    else:
      if os.path.exists("assets/hubert/hubert_base.pt_original"):
        # !mv assets/hubert/hubert_base.pt_original assets/hubert/hubert_base.pt
        print("Reverting to original Hubert Model.")
      else:
        print("Original Hubert Model not Found! Redownloading...")
        # !curl -LJ -o assets/hubert/hubert_base.pt $hubertpt
      if use_jp_hubert==True:
        print("Using JP Hubert Base")
      else:
        print("Using Original Hubert Base")
      Run_Cell=2

# %%
#@title Download Custom Pretrains
#@markdown ---
#@markdown This cell lets you download Custom pretrains made by the communitry from huggingface

#@markdown Custom pretrains will be located in ``assets/custom_pretrains/[name of creator]/[name of pretrain]``
if 'Run_Cell' not in globals():
  print("No, Go back to the first cell and run it!")
else:
  if Run_Cell == 0 or Run_Cell == 1:
    print("No, Go back to the first cell and run it!!!")
  else:
    #@markdown ---
    UseCustomPretrain = True #@param {type:"boolean"}
    CustomPretrain = "poiqazwsx/Ov2Super32kfix" # @param ["poiqazwsx/Ov2Super32kfix", "ORVC/Ov2Super", "ORVC/RIN_E3", "ORVC/Snowie_RuPretrain_48k", "ORVC/Snowie_RuPretrain_40k", "MUSTAR/SnowieV3.1-32k", "MUSTAR/SnowieV3.1-40k", "MUSTAR/SnowieV3.1-48k", "MUSTAR/SnowieV3.1-X-RinE3-40K", "MUSTAR/Snowie_V3.1_JP_hubert"] {allow-input: true}
    #@markdown ---
    #@markdown Custom Pretrains from huggingface

    # @markdown Examples:

    #@markdown ``ORVC/RIN_E3``
    #@markdown ``poiqazwsx/Ov2Super32kfix``
    #@markdown ``ORVC/Ov2Super``
    #@markdown ``ORVC/Snowie_RuPretrain_48k``
    #@markdown ``MUSTAR/SnowieV3.1-32k``
    #@markdown ``MUSTAR/SnowieV3.1-40k``
    #@markdown ``MUSTAR/SnowieV3.1-48k``
    #@markdown ``MUSTAR/SnowieV3.1-X-RinE3-40K``
    #@markdown ``MUSTAR/Snowie_V3.1_JP_hubert``

    import glob
    if UseCustomPretrain==True:
      # !mkdir temppretrains
      # !mkdir -p assets/custom_pretrain/{CustomPretrain}

      # !git clone https://huggingface.co/$CustomPretrain temppretrains

      # !mv temppretrains/*.pth assets/custom_pretrain/{CustomPretrain}
      # !rm -rf temppretrains/*


    clear_output()
    print(f"Downloaded {CustomPretrain}")

    # Get a list of all .pth files in the same directory as CustomPretrain
    pth_files = glob.glob(f"assets/custom_pretrain/{CustomPretrain}/*.pth")

    # Print the list of .pth files
    for pth_file in pth_files:
        print(pth_file)
    Run_Cell=3

# %%
#@title Theme Loader
#@markdown ---
#@markdown Select a theme to make the UI to your liking

if 'Run_Cell' not in globals():
    print("No, Go back to the first cell and run it")
else:
  if Run_Cell == 0 or Run_Cell == 1:
    print("No, Go back to the first cell and run it")
  else:
    import os
    Theme="ParityError/Interstellar" #@param {type:"string"}

    file_path = "runmain.py.txt"
    if os.path.exists(file_path):
        # !mv runmain.py.txt runmain.py
        # !cp runmain.py runmain.py.txt
    else:
        # !cp runmain.py runmain.py.txt

    Theme_Front, Theme_Back = Theme.split("/")
    #@markdown How to select a theme? \
    #@markdown Go to [Theme Gallery](https://huggingface.co/spaces/gradio/theme-gallery) \
    #@markdown Select a theme \
    #@markdown It should look something like [``ParityError/Interstellar``](https://huggingface.co/spaces/ParityError/Interstellar) \
    #@markdown [![](https://imgur.com/OCKb7za.png)](https://imgur.com/OCKb7za)

    # !sed -i 's/title/theme=\"{Theme_Front}\/{Theme_Back}\",title/' runmain.py

    print(f"Loaded Theme: {Theme}")
    Run_Cell=4

# %%
#@title Start Running
#@markdown ---
#@markdown Run and wait till the urls show up.
import os
import time
Tunnel = "Ngrok" #@param ["Ngrok","Cloudflared"]

if 'Run_Cell' not in globals():
    print("No, Go back to the first cell and run it")
else:
  if Run_Cell == 0 or Run_Cell == 1:
    print("No, Go back to the first cell and run it")
  else:
    #@markdown To put ngrok token, go to the side and press the key icon<br> On the name put ``Ngrok_Token`` and the Value to be your ngrok token
    #Load Tensorboard
    #@markdown
    if note_env==1:
      os.system(f"imjoy-elfinder --root-dir=/content/training --port 9876 &")
    elif note_env==2:
      os.system(f"imjoy-elfinder --root-dir=/kaggle/tmp/training --port 9876 &")
    else:
      os.system(f"imjoy-elfinder --root-dir=training --port 9876 &")

    if Tunnel == "Ngrok":
      #Load Ngrok
      if note_env==1:
        from google.colab import userdata
        Ngrok_Token=userdata.get('Ngrok_Token')
      else:
        Ngrok_Token=""

      from pyngrok import ngrok
      ngrok.set_auth_token(Ngrok_Token)
      ngrok.kill() #tries to close all active ngrok urls


      main_tunnel = ngrok.connect(9303)
      tens_tunnel = ngrok.connect(8077)
      file_tunnel = ngrok.connect(9876)
      clear_output()
      print("RVC URL:", main_tunnel.public_url)
      print("Tensorboard URL:", tens_tunnel.public_url)
      print("File URL:", file_tunnel.public_url)
    elif Tunnel == "Cloudflared":
      if note_env==2:
        print("Cloudflared does not work on kaggle")
      else:
        # Install Cloudflared
        # !curl -LO https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
        # !dpkg -i cloudflared-linux-amd64.deb
        # Delete log file
        # !rm -rf nohup.out
        # Run cloudflared
        # !nohup cloudflared tunnel --url localhost:9303 &
        # !nohup cloudflared tunnel --url localhost:8077 &
        # !nohup cloudflared tunnel --url localhost:9876 &
        clear_output()

        time.sleep(5)

        # !source .venv/bin/activate; grep -oE "https://[a-zA-Z0-9.-]+\.trycloudflare\.com" nohup.out


    # Launch Tensorboard
    if note_env==2:
      # Disable Share
      # !sed -i 's/share=True/share=False/g' runmain.py && sed -i 's/quiet=True,/quiet=True ,share=False/g' runmain.py


      if Tunnel=="Cloudflared":
        print("Ye no Cloudflared")

    # %load_ext tensorboard
    # %tensorboard --logdir logs --port 8077
    #Launch App

    # !source .venv/bin/activate; python runmain.py --pycmd python --port 9303

# %% [markdown]
# [![](https://i.pinimg.com/474x/de/72/9e/de729ecfa41b69901c42c82fff752414.jpg)](https://github.com/hinabl)
